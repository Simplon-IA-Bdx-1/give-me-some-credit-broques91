# %%
from pandas import read_csv
df = read_csv('https://oml-data.s3.amazonaws.com/kaggle-give-me-credit-train.csv')
df_test = read_csv('https://oml-data.s3.amazonaws.com/kaggle-give-me-credit-test.csv')
df.rename( columns={'Unnamed: 0' :'Id'}, inplace=True )
df_test.rename( columns={'Unnamed: 0' :'Id'}, inplace=True )
df
# Out:
#             Id  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1                              0.766127   45
# 1            2                              0.957151   40
# 2            3                              0.658180   38
# 3            4                              0.233810   30
# 4            5                              0.907239   49
# 5            6                              0.213179   74
# 6            7                              0.305682   57
# 7            8                              0.754464   39
# 8            9                              0.116951   27
# 9           10                              0.189169   57
# 10          11                              0.644226   30
# 11          12                              0.018798   51
# 12          13                              0.010352   46
# 13          14                              0.964673   40
# 14          15                              0.019657   76
# ...

# %%
df.describe()
# Out:
#                   Id  RevolvingUtilizationOfUnsecuredLines            age  \
# count  150000.000000                         150000.000000  150000.000000
# mean    75000.500000                              6.048438      52.295207
# std     43301.414527                            249.755371      14.771866
# min         1.000000                              0.000000       0.000000
# 25%     37500.750000                              0.029867      41.000000
# 50%     75000.500000                              0.154181      52.000000
# 75%    112500.250000                              0.559046      63.000000
# max    150000.000000                          50708.000000     109.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                         150000.000000  150000.000000   1.202690e+05
# mean                               0.421033     353.005076   6.670221e+03
# std                                4.192781    2037.818523   1.438467e+04
# ...

# %%
df[['DebtRatio', 'MonthlyIncome']]
df_test[['DebtRatio', 'MonthlyIncome']]
# Out:
#           DebtRatio  MonthlyIncome
# 0          0.177513         5700.0
# 1          0.527237         9141.0
# 2          0.687648         5083.0
# 3          0.925961         3200.0
# 4          0.019917         3865.0
# 5          0.342429         4140.0
# 6       1048.000000            0.0
# 7          0.369170         3301.0
# 8       2024.000000            NaN
# 9          0.000000            0.0
# 10         0.319687         7400.0
# 11         0.903552         4250.0
# 12         0.007782         3854.0
# 13         0.377449         2500.0
# 14         0.697347         6822.0
# 15         0.105831         7133.0
# 16         0.461786         5900.0
# 17         0.144326         2916.0
# 18         0.174850         4500.0
# 19       487.000000            NaN
# 20         0.196156         8844.0
# 21         0.353158        11920.0
# 22         0.384451         6083.0
# 23         0.666338         3041.0
# 24         0.286555         8500.0
# 25      3825.000000            NaN
# ...

# %%
df.fillna(0)
# Out:
#             Id  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1                              0.766127   45
# 1            2                              0.957151   40
# 2            3                              0.658180   38
# 3            4                              0.233810   30
# 4            5                              0.907239   49
# 5            6                              0.213179   74
# 6            7                              0.305682   57
# 7            8                              0.754464   39
# 8            9                              0.116951   27
# 9           10                              0.189169   57
# 10          11                              0.644226   30
# 11          12                              0.018798   51
# 12          13                              0.010352   46
# 13          14                              0.964673   40
# 14          15                              0.019657   76
# ...

# %%
df.astype({'NumberOfTime30-59DaysPastDueNotWorse': int, 'NumberOfTimes90DaysLate': int, 'NumberOfTime60-89DaysPastDueNotWorse' : int})
df_test.astype({'NumberOfTime30-59DaysPastDueNotWorse': int, 'NumberOfTimes90DaysLate': int, 'NumberOfTime60-89DaysPastDueNotWorse' : int})
# Out:
#             Id  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1               NaN                              0.885519   43
# 1            2               NaN                              0.463295   57
# 2            3               NaN                              0.043275   59
# 3            4               NaN                              0.280308   38
# 4            5               NaN                              1.000000   27
# 5            6               NaN                              0.509791   63
# 6            7               NaN                              0.587778   50
# 7            8               NaN                              0.046149   79
# 8            9               NaN                              0.013527   68
# 9           10               NaN                              1.000000   23
# 10          11               NaN                              0.028485   37
# ...

# %%
df
# Out:
#             Id  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1                              0.766127   45
# 1            2                              0.957151   40
# 2            3                              0.658180   38
# 3            4                              0.233810   30
# 4            5                              0.907239   49
# 5            6                              0.213179   74
# 6            7                              0.305682   57
# 7            8                              0.754464   39
# 8            9                              0.116951   27
# 9           10                              0.189169   57
# 10          11                              0.644226   30
# 11          12                              0.018798   51
# 12          13                              0.010352   46
# 13          14                              0.964673   40
# 14          15                              0.019657   76
# ...

# %%
df.insert( 6, 'NumberOfTimes30DaysOrLater', df['NumberOfTime30-59DaysPastDueNotWorse'] + 2*df['NumberOfTime60-89DaysPastDueNotWorse'] + 3*df['NumberOfTimes90DaysLate'])
df_test.insert( 6, 'NumberOfTimes30DaysOrLater', df_test['NumberOfTime30-59DaysPastDueNotWorse'] + 2*df_test['NumberOfTime60-89DaysPastDueNotWorse'] + 3*df_test['NumberOfTimes90DaysLate'])

# %%
df
# Out:
#             Id  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1                              0.766127   45
# 1            2                              0.957151   40
# 2            3                              0.658180   38
# 3            4                              0.233810   30
# 4            5                              0.907239   49
# 5            6                              0.213179   74
# 6            7                              0.305682   57
# 7            8                              0.754464   39
# 8            9                              0.116951   27
# 9           10                              0.189169   57
# 10          11                              0.644226   30
# 11          12                              0.018798   51
# 12          13                              0.010352   46
# 13          14                              0.964673   40
# 14          15                              0.019657   76
# ...

# %%
df.fillna(0)
df_test.fillna(0)
# Out:
#             Id  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1               0.0                              0.885519   43
# 1            2               0.0                              0.463295   57
# 2            3               0.0                              0.043275   59
# 3            4               0.0                              0.280308   38
# 4            5               0.0                              1.000000   27
# 5            6               0.0                              0.509791   63
# 6            7               0.0                              0.587778   50
# 7            8               0.0                              0.046149   79
# 8            9               0.0                              0.013527   68
# 9           10               0.0                              1.000000   23
# 10          11               0.0                              0.028485   37
# ...

# %%
df['MonthlyDebt'] = df['DebtRatio'].astype(float) * df['MonthlyIncome'].astype(float)
df_test['MonthlyDebt'] = df_test['DebtRatio'].astype(float) * df_test['MonthlyIncome'].astype(float)

# %%
df
# Out:
#             Id  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1                              0.766127   45
# 1            2                              0.957151   40
# 2            3                              0.658180   38
# 3            4                              0.233810   30
# 4            5                              0.907239   49
# 5            6                              0.213179   74
# 6            7                              0.305682   57
# 7            8                              0.754464   39
# 8            9                              0.116951   27
# 9           10                              0.189169   57
# 10          11                              0.644226   30
# 11          12                              0.018798   51
# 12          13                              0.010352   46
# 13          14                              0.964673   40
# 14          15                              0.019657   76
# ...

# %%
df['MonthlyIncome'].fillna(0)
df_test['MonthlyIncome'].fillna(0)
# Out:
# 0          5700.0
# 1          9141.0
# 2          5083.0
# 3          3200.0
# 4          3865.0
# 5          4140.0
# 6             0.0
# 7          3301.0
# 8             0.0
# 9             0.0
# 10         7400.0
# 11         4250.0
# 12         3854.0
# 13         2500.0
# 14         6822.0
# 15         7133.0
# 16         5900.0
# 17         2916.0
# 18         4500.0
# 19            0.0
# 20         8844.0
# 21        11920.0
# 22         6083.0
# 23         3041.0
# 24         8500.0
# 25            0.0
# 26         4750.0
# 27            0.0
# 28         7500.0
# 29            0.0
#            ...
# 101473     5333.0
# 101474     2036.0
# 101475     1284.0
# 101476     8400.0
# 101477     3000.0
# 101478     5833.0
# 101479     3608.0
# 101480     5257.0
# 101481     7043.0
# 101482     2000.0
# 101483     7636.0
# 101484     7500.0
# 101485     3917.0
# 101486     2983.0
# 101487        0.0
# 101488     7550.0
# 101489     3333.0
# 101490     9500.0
# 101491     8958.0
# ...

# %%
df
# Out:
#             Id  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1                              0.766127   45
# 1            2                              0.957151   40
# 2            3                              0.658180   38
# 3            4                              0.233810   30
# 4            5                              0.907239   49
# 5            6                              0.213179   74
# 6            7                              0.305682   57
# 7            8                              0.754464   39
# 8            9                              0.116951   27
# 9           10                              0.189169   57
# 10          11                              0.644226   30
# 11          12                              0.018798   51
# 12          13                              0.010352   46
# 13          14                              0.964673   40
# 14          15                              0.019657   76
# ...

# %%
df['MonthlyIncome']
# Out:
# 0          9120.0
# 1          2600.0
# 2          3042.0
# 3          3300.0
# 4         63588.0
# 5          3500.0
# 6             NaN
# 7          3500.0
# 8             NaN
# 9         23684.0
# 10         2500.0
# 11         6501.0
# 12        12454.0
# 13        13700.0
# 14            0.0
# 15        11362.0
# 16            NaN
# 17         8800.0
# 18         3280.0
# 19          333.0
# 20        12300.0
# 21         3000.0
# 22         2500.0
# 23         7916.0
# 24         2416.0
# 25         4676.0
# 26         8333.0
# 27         2500.0
# 28         3400.0
# 29         5500.0
#            ...
# 149970    15500.0
# 149971     5000.0
# 149972     6945.0
# 149973     5500.0
# 149974     5000.0
# 149975        NaN
# 149976        NaN
# 149977        NaN
# 149978     2500.0
# 149979     8700.0
# 149980     5525.0
# 149981     6849.0
# 149982     2760.0
# 149983     5000.0
# 149984        NaN
# 149985     1950.0
# 149986     5000.0
# 149987     3249.0
# 149988     7515.0
# ...

# %%
df.fillna(0)
# Out:
#             Id  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1                              0.766127   45
# 1            2                              0.957151   40
# 2            3                              0.658180   38
# 3            4                              0.233810   30
# 4            5                              0.907239   49
# 5            6                              0.213179   74
# 6            7                              0.305682   57
# 7            8                              0.754464   39
# 8            9                              0.116951   27
# 9           10                              0.189169   57
# 10          11                              0.644226   30
# 11          12                              0.018798   51
# 12          13                              0.010352   46
# 13          14                              0.964673   40
# 14          15                              0.019657   76
# ...

# %%
df['isOld'] = df.loc[df.age > 70] = 1
df_test['isOld'] = df_test.loc[df.age > 70] = 1

# %%
df
# Out:
#             Id  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1                              0.766127   45
# 1            2                              0.957151   40
# 2            3                              0.658180   38
# 3            4                              0.233810   30
# 4            5                              0.907239   49
# 5            1                              1.000000    1
# 6            7                              0.305682   57
# 7            8                              0.754464   39
# 8            9                              0.116951   27
# 9           10                              0.189169   57
# 10          11                              0.644226   30
# 11          12                              0.018798   51
# 12          13                              0.010352   46
# 13          14                              0.964673   40
# 14           1                              1.000000    1
# ...

# %%
df
# Out:
#             Id  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1                              0.766127   45
# 1            2                              0.957151   40
# 2            3                              0.658180   38
# 3            4                              0.233810   30
# 4            5                              0.907239   49
# 5            1                              1.000000    1
# 6            7                              0.305682   57
# 7            8                              0.754464   39
# 8            9                              0.116951   27
# 9           10                              0.189169   57
# 10          11                              0.644226   30
# 11          12                              0.018798   51
# 12          13                              0.010352   46
# 13          14                              0.964673   40
# 14           1                              1.000000    1
# ...

# %%
df
# Out:
#             Id  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1                              0.766127   45
# 1            2                              0.957151   40
# 2            3                              0.658180   38
# 3            4                              0.233810   30
# 4            5                              0.907239   49
# 5            1                              1.000000    1
# 6            7                              0.305682   57
# 7            8                              0.754464   39
# 8            9                              0.116951   27
# 9           10                              0.189169   57
# 10          11                              0.644226   30
# 11          12                              0.018798   51
# 12          13                              0.010352   46
# 13          14                              0.964673   40
# 14           1                              1.000000    1
# ...

# %%
df.fillna(0)
df_test.fillna(0)
# Out:
#             Id  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1               0.0                              0.885519   43
# 1            2               0.0                              0.463295   57
# 2            3               0.0                              0.043275   59
# 3            4               0.0                              0.280308   38
# 4            5               0.0                              1.000000   27
# 5            6               0.0                              0.509791   63
# 6            7               0.0                              0.587778   50
# 7            8               0.0                              0.046149   79
# 8            9               0.0                              0.013527   68
# 9           10               0.0                              1.000000   23
# 10          11               0.0                              0.028485   37
# ...

# %%
df['isOld'] = df['age'].apply(lambda x: 1 if x > 70 else 0)
df_test['isOld'] = df_test['age'].apply(lambda x: 1 if x > 70 else 0)

# %%
df
# Out:
#             Id  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1                              0.766127   45
# 1            2                              0.957151   40
# 2            3                              0.658180   38
# 3            4                              0.233810   30
# 4            5                              0.907239   49
# 5            1                              1.000000    1
# 6            7                              0.305682   57
# 7            8                              0.754464   39
# 8            9                              0.116951   27
# 9           10                              0.189169   57
# 10          11                              0.644226   30
# 11          12                              0.018798   51
# 12          13                              0.010352   46
# 13          14                              0.964673   40
# 14           1                              1.000000    1
# ...

# %%
df['MonthlyDebt'] = df['DebtRatio'].astype(float) * df['MonthlyIncome'].astype(float)
df_test['MonthlyDebt'] = df_test['DebtRatio'].astype(float) * df_test['MonthlyIncome'].astype(float)

# %%
df.fillna(0)
df_test.fillna(0)
# Out:
#             Id  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1               0.0                              0.885519   43
# 1            2               0.0                              0.463295   57
# 2            3               0.0                              0.043275   59
# 3            4               0.0                              0.280308   38
# 4            5               0.0                              1.000000   27
# 5            6               0.0                              0.509791   63
# 6            7               0.0                              0.587778   50
# 7            8               0.0                              0.046149   79
# 8            9               0.0                              0.013527   68
# 9           10               0.0                              1.000000   23
# 10          11               0.0                              0.028485   37
# ...

# %%
df
# Out:
#             Id  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1                              0.766127   45
# 1            2                              0.957151   40
# 2            3                              0.658180   38
# 3            4                              0.233810   30
# 4            5                              0.907239   49
# 5            1                              1.000000    1
# 6            7                              0.305682   57
# 7            8                              0.754464   39
# 8            9                              0.116951   27
# 9           10                              0.189169   57
# 10          11                              0.644226   30
# 11          12                              0.018798   51
# 12          13                              0.010352   46
# 13          14                              0.964673   40
# 14           1                              1.000000    1
# ...

# %%
df = df.replace('NaN', 0)

# %%
df
# Out:
#             Id  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1                              0.766127   45
# 1            2                              0.957151   40
# 2            3                              0.658180   38
# 3            4                              0.233810   30
# 4            5                              0.907239   49
# 5            1                              1.000000    1
# 6            7                              0.305682   57
# 7            8                              0.754464   39
# 8            9                              0.116951   27
# 9           10                              0.189169   57
# 10          11                              0.644226   30
# 11          12                              0.018798   51
# 12          13                              0.010352   46
# 13          14                              0.964673   40
# 14           1                              1.000000    1
# ...

# %%
df
# Out:
#             Id  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1                              0.766127   45
# 1            2                              0.957151   40
# 2            3                              0.658180   38
# 3            4                              0.233810   30
# 4            5                              0.907239   49
# 5            1                              1.000000    1
# 6            7                              0.305682   57
# 7            8                              0.754464   39
# 8            9                              0.116951   27
# 9           10                              0.189169   57
# 10          11                              0.644226   30
# 11          12                              0.018798   51
# 12          13                              0.010352   46
# 13          14                              0.964673   40
# 14           1                              1.000000    1
# ...

# %%
df['MonthlyIncome'].fillna(0, inplace = True)

# %%
df
# Out:
#             Id  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1                              0.766127   45
# 1            2                              0.957151   40
# 2            3                              0.658180   38
# 3            4                              0.233810   30
# 4            5                              0.907239   49
# 5            1                              1.000000    1
# 6            7                              0.305682   57
# 7            8                              0.754464   39
# 8            9                              0.116951   27
# 9           10                              0.189169   57
# 10          11                              0.644226   30
# 11          12                              0.018798   51
# 12          13                              0.010352   46
# 13          14                              0.964673   40
# 14           1                              1.000000    1
# ...

# %%
df['NumberOfDependents'].fillna('', inplace = True)

# %%
df
# Out:
#             Id  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1                              0.766127   45
# 1            2                              0.957151   40
# 2            3                              0.658180   38
# 3            4                              0.233810   30
# 4            5                              0.907239   49
# 5            1                              1.000000    1
# 6            7                              0.305682   57
# 7            8                              0.754464   39
# 8            9                              0.116951   27
# 9           10                              0.189169   57
# 10          11                              0.644226   30
# 11          12                              0.018798   51
# 12          13                              0.010352   46
# 13          14                              0.964673   40
# 14           1                              1.000000    1
# ...

# %%
df['MonthlyDebt'].fillna(0, inplace = True)

# %%
df
# Out:
#             Id  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1                              0.766127   45
# 1            2                              0.957151   40
# 2            3                              0.658180   38
# 3            4                              0.233810   30
# 4            5                              0.907239   49
# 5            1                              1.000000    1
# 6            7                              0.305682   57
# 7            8                              0.754464   39
# 8            9                              0.116951   27
# 9           10                              0.189169   57
# 10          11                              0.644226   30
# 11          12                              0.018798   51
# 12          13                              0.010352   46
# 13          14                              0.964673   40
# 14           1                              1.000000    1
# ...

# %%
from bigml.api import BigML

# %%
# %env BIGML_USERNAME=broques91
# %env BIGML_API_KEY=1182c95d3842b99c93364b3f5cb66894ba0f54c0
# Out:
# env: BIGML_USERNAME=broques91
# env: BIGML_API_KEY=1182c95d3842b99c93364b3f5cb66894ba0f54c0

# %%
api = BigML()

# %%
df.to_csv('pandaTrain.csv')
df_test.to_csv('pandaTest.csv')

# %%
source = api.create_source('pandaTrain.csv')
test = api.create_source('pandaTest.csv')

# %%
api.ok(source)
# Out:
# True

# %%
source = api.create_source('pandaTrain.csv')

# %%
api.ok(source)
# Out:
# True

# %%
from bigml.api import BigML

# %%
api = BigML('broques91', '1182c95d3842b99c93364b3f5cb66894ba0f54c0',
            project='project/5d9b851042129f40b70001b0')

# %%
source = api.create_source('pandaTrain.csv')
test = api.create_source('pandaTest.csv')

# %%
api.ok(source)
# Out:
# True

# %%
dataset_args = {"name": "pandaTrainFull"}
dataset = api.create_dataset(source, dataset_args)
dataset2_args = {"name": "pandaTest"}
dataset2 = api.create_dataset(test, dataset2_args)

# %%
train_dataset = api.create_dataset(
    dataset, {"name": "pandaTrain | Training (80%)",
                     "sample_rate": 0.8, "seed": "my seed"})
test_dataset = api.create_dataset(
    dataset, {"name": "pandaTrain | Val (20%)",
                     "sample_rate": 0.8, "seed": "my seed",
                     "out_of_bag": True})

# %%
ensemble_args = {"objective_field": "SeriousDlqin2yrs"}
ensemble = api.create_ensemble(train_dataset, ensemble_args)

# %%
batch_prediction = api.create_batch_prediction(ensemble, test_dataset,
                                               {"all_fields": True})

# %%
api.ok(batch_prediction)
# Out:
# True

# %%
api.download_batch_prediction(batch_prediction,
                              filename='pandaPredictions2.csv')
# Out:
# 'pandaPredictions2.csv'

# %%
evaluation = api.create_evaluation(ensemble, test_dataset)

# %%
api.ok(evaluation)
# Out:
# True

# %%
ensemble_args = {"objective_field": "SeriousDlqin2yrs"}
ensemble = api.create_ensemble(train_dataset, ensemble_args)

# %%
batch_prediction = api.create_batch_prediction(ensemble, dataset2,
                                               {"output_fields": ["Id"], "probabilities": True})

# %%
api.ok(batch_prediction)
# Out:
# True

# %%
api.download_batch_prediction(batch_prediction,
                              filename='my_predictions.csv')
# Out:
# 'my_predictions.csv'

# %%
df_kaggle=read_csv('my_predictions.csv')

# %%
df_kaggle = df_kaggle.drop(["SeriousDlqin2yrs", "0 probability"], axis=1)

# %% [markdown]
# # df_kaggle

# %%
df_kaggle = df_kaggle.rename(columns={"1 probability": "Probability"})

# %%
df_kaggle
# Out:
#             Id  Probability
# 0            1      0.05365
# 1            2      0.03780
# 2            3      0.01436
# 3            4      0.06891
# 4            5      0.08854
# 5            6      0.03784
# 6            7      0.04330
# 7            8      0.03759
# 8            9      0.01004
# 9           10      0.49351
# 10          11      0.01790
# 11          12      0.02835
# 12          13      0.00750
# 13          14      0.02222
# 14          15      0.02983
# 15          16      0.03241
# 16          17      0.02211
# 17          18      0.01956
# 18          19      0.20955
# 19          20      0.07224
# 20          21      0.00976
# 21          22      0.01512
# 22          23      0.01329
# 23          24      0.36032
# 24          25      0.08384
# 25          26      0.01447
# 26          27      0.10930
# 27          28      0.01004
# 28          29      0.04389
# 29          30      0.01755
# ...        ...          ...
# 101473  101474      0.03417
# ...

# %%
df_kaggle.to_csv('kaggle_predictions.csv', index=False)

# %%
import kaggle
submission_file='kaggle_predictions.csv'
kaggle.api.competition_submit(submission_file, "BigML Ensemble", "GiveMeSomeCredit")
# Out:
# 100%|██████████| 1.64M/1.64M [00:05<00:00, 339kB/s]
# Successfully submitted to Give Me Some Credit
